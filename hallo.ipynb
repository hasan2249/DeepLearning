# %% [markdown]
# <a href="https://colab.research.google.com/github/hasan2249/DeepLearning/blob/main/hallo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://huggingface.co/spaces/hasan93/hallo-talking-face
# Out:
# Cloning into 'hallo-talking-face'...
# remote: Enumerating objects: 168, done.
# remote: Total 168 (delta 0), reused 0 (delta 0), pack-reused 168 (from 1)
# Receiving objects: 100% (168/168), 1.79 MiB | 11.33 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
# %cd hallo-talking-face
# !python -m pip install -r requirements.txt
# Out:
# [Errno 2] No such file or directory: 'hallo-talking-face'
# /content/hallo-talking-face
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.5/439.5 kB 11.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.1/157.1 kB 7.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !python -m pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.9/321.9 kB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 464.1/464.1 kB 21.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 88.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.25.2
#     Uninstalling huggingface-hub-0.25.2:
#       Successfully uninstalled huggingface-hub-0.25.2
# ...

# %%
# !python -m pip install huggingface-hub==0.23.2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.7/401.7 kB 7.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.28.1
#     Uninstalling huggingface-hub-0.28.1:
#       Successfully uninstalled huggingface-hub-0.28.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 5.16.0 requires huggingface-hub>=0.28.1, but you have huggingface-hub 0.23.2 which is incompatible.
# peft 0.14.0 requires huggingface-hub>=0.25.0, but you have huggingface-hub 0.23.2 which is incompatible.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.39.2 which is incompatible.
# ...

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
import os

os.environ['SPACE_ID'] = 'fffiloni/tts-hallo-talking-portrait'

# %%
# !python app.py
# Out:
# Streaming output truncated to the last 5000 lines.
#
# net.pth:   6% 273M/4.85G [00:23<11:08, 6.85MB/s]
#
#
#
#
#
# model.safetensors:  75% 283M/378M [00:20<00:05, 16.4MB/s]
#
#
# mm_sd_v15_v2.ckpt:  18% 325M/1.82G [00:22<01:58, 12.6MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  88% 294M/335M [00:22<00:04, 9.93MB/s]
#
#
#
#
#
#
# net.pth:   6% 283M/4.85G [00:23<08:11, 9.29MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   8% 273M/3.44G [00:22<04:54, 10.8MB/s]
#
#
#
#
#
# model.safetensors:  78% 294M/378M [00:21<00:04, 19.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   8% 283M/3.44G [00:22<03:48, 13.8MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  91% 304M/335M [00:22<00:02, 12.6MB/s]
#
#
#
#
#
#
# net.pth:   6% 294M/4.85G [00:23<06:22, 11.9MB/s]
#
#
#
#
#
# model.safetensors:  81% 304M/378M [00:21<00:03, 22.6MB/s]
#
#
#
#
#
#
# net.pth:   6% 304M/4.85G [00:23<04:44, 16.0MB/s]
#
#
# mm_sd_v15_v2.ckpt:  18% 336M/1.82G [00:23<01:50, 13.5MB/s]
#
#
#
#
# ...
